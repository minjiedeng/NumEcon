# %% [markdown]
# # Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# %aimport utility

from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e2f74091-29f0-4e27-a385-9ef59d6a4d94">Loading BokehJS ...</span>
#     </div>

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %% [markdown]
# # Cobb-Dogulas

# %% [markdown]
# $$u(x_1,x_2) = x_1^{\alpha}x_2^{\beta}$$

# %%
utility.cobb_douglas()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="98b97dad-d35c-4b26-a91c-0f059e30cf24"></div>
# </div>
# interactive(children=(FloatSlider(value=0.5, description='alpha', max=0.95, min=0.05, step=0.05), FloatSlider(…

# %% [markdown]
# # Constant Elasticity of Substitution (CES)

# %% [markdown]
# $$u(x_1,x_2) = (\alpha x_1^{-\beta}+(1-\alpha)x_2^{-\beta})^{-1/\beta}$$

# %%
utility.ces()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="9e3a91c5-ee28-419b-94aa-6954046897e3"></div>
# </div>
# interactive(children=(FloatSlider(value=0.5, description='alpha', max=0.95, min=0.05, step=0.05), FloatSlider(…

# %% [markdown]
# # Perfect substitutes

# %% [markdown]
# $$u(x_1,x_2) = \alpha x_1 + \beta x_2$$

# %%
utility.perfect_substitutes()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="267834f6-2c2d-46d2-a9ab-67834e50cbc3"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=3.0, min=0.05, step=0.05), FloatSlider(v…

# %% [markdown]
# # Perfect complements

# %% [markdown]
# $$u(x_1,x_2) = \min{\{\alpha x_1 + \beta x_2}\}$$

# %%
utility.perfect_complements()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3b055e16-b633-41e0-ab2d-fae878b94dab"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=3.0, min=0.05, step=0.05), FloatSlider(v…

# %% [markdown]
# # Quasi-linear (case 1)

# %% [markdown]
# $$u(x_1,x_2) = \alpha\log(x_1) + \beta x_2$$

# %%
utility.quasi_linear_case_1()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0c0cfcf7-1333-4a71-b0cb-275c26bc336e"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=3.0, min=0.05, step=0.05), FloatSlider(v…

# %% [markdown]
# # Quasi-linear (case 2)

# %% [markdown]
# $$u(x_1,x_2) = \alpha\sqrt(x_1) + \beta x_2$$

# %%
utility.quasi_linear_case_2()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="72950c47-60a9-48d3-a132-e568ba5cd7f6"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=3.0, min=0.05, step=0.05), FloatSlider(v…

# %% [markdown]
# # Arbitrary function

# %% [markdown]
# $$ u(x_1,x_2,) = f(x_1,x_2,\alpha,\beta)$$

# %% [markdown]
# ## Cobb-Douglas once again

# %%
def my_utility_func(x1,x2,alpha,beta):
    return x1**alpha*x2**beta

alpha = 0.50
beta = 0.50
alpha_bounds = [0.05,0.95]
beta_bounds = [0.05,0.95]

utility.arbitrary(my_utility_func,alpha,beta,alpha_bounds,beta_bounds,plot_type='line')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="765ab174-8f65-498d-9256-838a5be769da"></div>
# </div>
# interactive(children=(FloatSlider(value=0.5, description='alpha', max=0.95, min=0.05, step=0.05), FloatSlider(…

# %% [markdown]
# ## Non-monotone preferences

# %%
def my_utility_func(x1,x2,alpha,beta):
    return -((x1-alpha)**2+(x2-beta)**2)

alpha = 5.0
beta = 5.0
alpha_bounds = [3,7]
beta_bounds = [3,7]

utility.arbitrary(my_utility_func,alpha,beta,alpha_bounds,beta_bounds,plot_type='scatter')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="97d0f57f-15cc-4053-9399-a19071f36be8"></div>
# </div>
# interactive(children=(FloatSlider(value=5.0, description='alpha', max=7.0, min=3.0, step=0.05), FloatSlider(va…
