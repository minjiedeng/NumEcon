# %% [markdown]
# # Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# %aimport utilitymax

from bokeh.io import output_notebook
output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="46ae756d-8a54-44e3-808b-44081aeae6ab">Loading BokehJS ...</span>
#     </div>

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %% [markdown]
# # Budget set

# %% [markdown]
# $$C(p_1,p_2,I) = \{(x_1,x_2) \in \mathbb{R}_{+}^2 \,\, | \,\, p_1 x_1 + p_2 x_2 \leq I\} $$

# %% [markdown]
# # Cobb-Dogulas

# %% [markdown]
# $$u(x_1,x_2) = x_1^{\alpha}x_2^{\beta}$$

# %%
utilitymax.cobb_douglas()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="72571445-0f9e-442b-8ec4-a9d323612542"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %% [markdown]
# # Constant Elasticity of Substitution (CES)

# %% [markdown]
# $$u(x_1,x_2) = (\alpha x_1^{-\beta}+(1-\alpha)x_2^{-\beta})^{-1/\beta}$$

# %%
utilitymax.ces()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a860e8ad-c36f-43c6-9a62-b1fbe082fc2a"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %% [markdown]
# # Perfect substitutes

# %% [markdown]
# $$u(x_1,x_2) = \alpha x_1 + \beta x_2$$

# %%
utilitymax.perfect_substitutes()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3ae5d5ea-a123-4afd-ab84-f7cff494008b"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %% [markdown]
# # Perfect complements

# %% [markdown]
# $$u(x_1,x_2) = \min{\{\alpha x_1 + \beta x_2}\}$$

# %%
utilitymax.perfect_complements()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b70ee56d-233a-473e-84b4-a35853b0a144"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %% [markdown]
# # Quasi-linear (case 1)

# %% [markdown]
# $$u(x_1,x_2) = \alpha\log(x_1) + \beta x_2$$

# %%
utilitymax.quasi_linear_case_1()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="826f27c9-5ec4-479e-bace-4e79ed36d289"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %% [markdown]
# # Quasi-linear (case 2)

# %% [markdown]
# $$u(x_1,x_2) = \alpha\sqrt(x_1) + \beta x_2$$

# %%
utilitymax.quasi_linear_case_2()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2fd2178e-94b0-49ec-8eee-24dcfdef1936"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %%
def my_utility_func(x1,x2,alpha,beta):
    return x1**alpha*x2**beta

# a. budgetset
p1 = 1
p2 = 1
I = 10
p1_bounds = [0.05,4]
p2_bounds = [0.05,4]
I_bounds = [0.50,20]

# b. utility
alpha = 0.50
beta = 0.50
alpha_bounds = [0.05,0.95]
beta_bounds = [0.05,0.95]

utilitymax.arbitrary(my_utility_func,alpha,beta,alpha_bounds,beta_bounds,p1,p2,I,p1_bounds,p2_bounds,I_bounds,plot_type='line')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="96a4add2-22c3-4238-b865-724e997b56d4"></div>
# </div>
# interactive(children=(FloatSlider(value=1.0, description='p1', max=4.0, min=0.05, step=0.05), FloatSlider(valu…

# %%
def my_utility_func(x1,x2,alpha,beta):
    return -((x1-alpha)**2+(x2-beta)**2)

alpha = 5.0
beta = 5.0
alpha_bounds = [3,7]
beta_bounds = [3,7]

utility.arbitrary(my_utility_func,alpha,beta,alpha_bounds,beta_bounds,plot_type='scatter')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="97d0f57f-15cc-4053-9399-a19071f36be8"></div>
# </div>
# interactive(children=(FloatSlider(value=5.0, description='alpha', max=7.0, min=3.0, step=0.05), FloatSlider(va…
