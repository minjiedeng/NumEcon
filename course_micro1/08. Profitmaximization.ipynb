# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Production-function" data-toc-modified-id="Production-function-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Production function</a></span></li><li><span><a href="#Long--vs.-short-run-costs" data-toc-modified-id="Long--vs.-short-run-costs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Long- vs. short-run costs</a></span><ul class="toc-item"><li><span><a href="#Total-costs" data-toc-modified-id="Total-costs-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Total costs</a></span></li><li><span><a href="#Average-costs" data-toc-modified-id="Average-costs-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Average costs</a></span></li><li><span><a href="#Marginal-costs" data-toc-modified-id="Marginal-costs-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Marginal costs</a></span></li></ul></li><li><span><a href="#Supply" data-toc-modified-id="Supply-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Supply</a></span></li><li><span><a href="#Cobb-Douglas-Supply-Function" data-toc-modified-id="Cobb-Douglas-Supply-Function-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cobb-Douglas Supply Function</a></span></li></ul></div>

# %% [markdown]
# **Description:** This is a Jupyter Notebook with Python code. You do not need any knowledge or either Jupyter or Python to run it.
#
# **To run all:** Kernel $\rightarrow$ Restart & Run All
#
# **To run each cell press:**
#
# 1. <kbd>Ctrl</kbd>+<kbd>Enter</kbd> to just run the cell
# 2. <kbd>Ctrl</kbd>+<kbd>Shift</kbd>+<kbd>Enter</kbd> to the run the cell and proceed to the next

# %%
# imports and settings
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import context
import numecon.course_micro1.profitmax as profitmax
# %aimport numecon.course_micro1.profitmax

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %% [markdown]
# # Production function

# %%
#calculations

from types import SimpleNamespace
par = SimpleNamespace()
par.alpha = 100
par.beta = 5
par.gamma = 5

l_vec = np.linspace(0,15,200)
k_vec = np.linspace(0,15,200)
ff = np.empty((l_vec.size,k_vec.size))

for i1,l in enumerate(l_vec):
    for i2,k in enumerate(k_vec):
        ff[i1,i2] = profitmax.f(l,k,par)

# figure
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(1,2,1,projection='3d')

l,k = np.meshgrid(l_vec,k_vec,indexing='ij')
ax.plot_surface(l,k,ff,cmap=cm.viridis)

ax.set_xlabel('$l$')
ax.set_ylabel('$k$')
ax.set_zlabel('$f(l,k)$')
ax.invert_xaxis()
ax.set_title('Production function')

ax = fig.add_subplot(1,2,2)

l,k = np.meshgrid(l_vec,k_vec,indexing='ij')
ax.contour(l,k,ff,50,cmap=cm.viridis)

ax.set_xlabel('$l$')
ax.set_ylabel('$k$')
ax.set_title('Isoquants');

# %% [markdown]
# # Long- vs. short-run costs

# %% [markdown]
# ## Total costs

# %%
profitmax.cost_figure()
# Out:
# interactive(children=(FloatSlider(value=8.0, description='$\\bar{k}$', max=20.0, min=1.0), Output()), _dom_cla…

# %% [markdown]
# ## Average costs

# %%
profitmax.avg_cost_figure()
# Out:
# interactive(children=(FloatSlider(value=8.0, description='$\\bar{k}$', max=20.0, min=1.0), Output()), _dom_cla…

# %% [markdown]
# ## Marginal costs

# %%
profitmax.MC_figure()
# Out:
# interactive(children=(FloatSlider(value=8.0, description='$\\bar{k}$', max=20.0, min=1.0), Output()), _dom_cla…

# %% [markdown]
# # Supply

# %%
profitmax.supply_figure()
# Out:
# interactive(children=(FloatSlider(value=5.0, description='$p$', max=20.0), FloatSlider(value=20.0, description…

# %% [markdown]
# # Cobb-Douglas Supply Function

# %%
#code
profitmax.cobb_douglas_output_figure()
# Out:
# interactive(children=(FloatSlider(value=64.0, description='$\\bar{k}$', max=256.0, min=8.0, step=8.0), Output(…
